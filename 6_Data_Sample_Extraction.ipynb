# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivani-781/Ganga-Water-Quality-Assessment/blob/main/6_Data_Sample_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Random Sample Extraction

# %%
import numpy as np
import pandas as pd

# %%
g1 = pd.read_csv('g1.csv')
print(g1.shape)
g2 = pd.read_csv('g2.csv')
print(g2.shape)
g3 = pd.read_csv('g3.csv')
print(g3.shape)
g4 = pd.read_csv('g4.csv')
print(g4.shape)
g5 = pd.read_csv('g5.csv')
print(g5.shape)
g6 = pd.read_csv('g6.csv')
print(g6.shape)
g7 = pd.read_csv('g7.csv')
print(g7.shape)
g8 = pd.read_csv('g8.csv')
print(g8.shape)
g9 = pd.read_csv('g9.csv')
print(g9.shape)
g10 = pd.read_csv('g10.csv')
print(g10.shape)
g11 = pd.read_csv('g11.csv')
print(g11.shape)
g12 = pd.read_csv('g12.csv')
print(g12.shape)
g13 = pd.read_csv('g13.csv')
print(g13.shape)
g14 = pd.read_csv('g14.csv')
print(g14.shape)
g15 = pd.read_csv('g15.csv')
print(g15.shape)
g16 = pd.read_csv('g16.csv')
print(g16.shape)
g17 = pd.read_csv('g17.csv')
print(g17.shape)
g18 = pd.read_csv('g18.csv')
print(g18.shape)
g19 = pd.read_csv('g19.csv')
print(g19.shape)
g20 = pd.read_csv('g20.csv')
print(g20.shape)
g21 = pd.read_csv('g21.csv')
print(g21.shape)
# Out:
# (70, 8)
# (79, 8)
# (3304, 8)
# (2855, 8)
# (0, 8)
# (1, 8)
# (107, 8)
# (0, 8)
# (0, 8)
# (0, 8)
# (83, 8)
# (0, 8)
# (0, 8)
# (1499, 8)
# (0, 8)
# (1, 8)
# (0, 8)
# (0, 8)
# (0, 8)
# (4, 8)
# (84, 8)

# %% [markdown]
# Selecting Random Samples

# %% [markdown]
# Sample 1

# %%
g_sample_1 = [g1.head(50), g2.head(50), g3.head(50), g4.head(50), g7.head(50), g11.head(50), g14.head(50), g21.head(50)]
g_data_1 = pd.concat(g_sample_1)

# %%
g_data_1
# Out:
#                    Date  Frame No   BAT        COND         DO       ORP  \
# 0   2019-01-12 14:54:00         0  90.0   46.195190  13.501176  0.142900
# 1   2019-01-12 14:55:00         1  91.0   52.609680  20.752865  0.146236
# 2   2019-01-12 14:56:00         2  91.0   52.399826  12.409351  0.146724
# 3   2019-01-12 14:57:00         3  92.0   41.708813  13.330035  0.143533
# 4   2019-01-12 14:58:00         4  90.0   52.926560  10.858296  0.142336
# ..                  ...       ...   ...         ...        ...       ...
# 45  2020-03-05 16:03:00        98  98.0  718.676800  16.458600  0.121643
# 46  2020-03-05 16:04:00        99  96.0  718.613650  13.028291  0.121814
# 47  2020-03-05 16:05:00       100  96.0  718.462950  13.455955  0.121636
# 48  2020-03-05 16:06:00       101  96.0  718.229000  13.773285  0.121644
# 49  2020-03-05 16:07:00       102  96.0  718.310000  14.439819  0.121749
#
#            PH         WT
# 0   12.359906  18.400787
# 1   12.825684  18.013641
# ...

# %%
g_data_1.to_csv('g_data_1.csv', index = False)

# %% [markdown]
# Sample 2

# %%
g_sample_2 = [g1.head(30), g2.head(30), g3.head(30), g4.head(30), g7.head(30), g11.head(30), g14.head(30), g21.head(30)]
g_data_2 = pd.concat(g_sample_2)

# %%
g_data_2
# Out:
#                    Date  Frame No   BAT        COND         DO       ORP  \
# 0   2019-01-12 14:54:00         0  90.0   46.195190  13.501176  0.142900
# 1   2019-01-12 14:55:00         1  91.0   52.609680  20.752865  0.146236
# 2   2019-01-12 14:56:00         2  91.0   52.399826  12.409351  0.146724
# 3   2019-01-12 14:57:00         3  92.0   41.708813  13.330035  0.143533
# 4   2019-01-12 14:58:00         4  90.0   52.926560  10.858296  0.142336
# ..                  ...       ...   ...         ...        ...       ...
# 25  2020-03-05 15:42:00        78  97.0  717.642330  18.589476  0.118812
# 26  2020-03-05 15:43:00        79  98.0  717.864870  16.642284  0.119013
# 27  2020-03-05 15:44:00        80  96.0  717.825740  16.265455  0.119212
# 28  2020-03-05 15:45:00        81  96.0  717.836200  16.833710  0.119398
# 29  2020-03-05 15:46:00        82  96.0  717.845950  15.290481  0.119665
#
#            PH         WT
# 0   12.359906  18.400787
# 1   12.825684  18.013641
# ...

# %%
g_data_2.to_csv('g_data_2.csv', index = False)

# %% [markdown]
# Sample 3

# %%
g_sample_3 = [g1[20:40], g2[20:40], g3[20:40], g4[20:40], g7[20:40], g11[20:40], g14[20:40], g21[20:40]]
g_data_3 = pd.concat(g_sample_3)

# %%
g_data_3
# Out:
#                    Date  Frame No   BAT        COND         DO       ORP  \
# 20  2019-01-12 15:14:00        20  90.0   54.571686   8.781806  0.144138
# 21  2019-01-12 15:15:00        21  91.0   54.098644   8.612140  0.143724
# 22  2019-01-12 15:16:00        22  90.0   54.124638   8.463595  0.143710
# 23  2019-01-12 15:17:00        23  90.0   53.287600   8.397623  0.144098
# 24  2019-01-12 15:19:00        24  91.0   53.866000   8.649648  0.143933
# ..                  ...       ...   ...         ...        ...       ...
# 35  2020-03-05 15:53:00        88  97.0  718.192500  16.467918  0.120692
# 36  2020-03-05 15:54:00        89  96.0  718.288600  15.885684  0.120835
# 37  2020-03-05 15:55:00        90  97.0  718.007400  15.181767  0.120850
# 38  2020-03-05 15:56:00        91  96.0  718.450200  13.872573  0.120954
# 39  2020-03-05 15:57:00        92  96.0  718.455000  14.715279  0.121095
#
#            PH         WT
# 20  13.271490  18.448700
# 21  13.328059  18.232513
# ...

# %%
g_data_3.to_csv('g_data_3.csv', index = False)

# %% [markdown]
# Sample 4

# %%
g_sample_4 = [g1[0:70], g2[0:70], g3[0:70], g4[0:70], g7[0:70], g11[0:70], g14[0:70], g21[0:70]]
g_data_4 = pd.concat(g_sample_4)

# %%
g_data_4
# Out:
#                    Date  Frame No   BAT        COND         DO       ORP  \
# 0   2019-01-12 14:54:00         0  90.0   46.195190  13.501176  0.142900
# 1   2019-01-12 14:55:00         1  91.0   52.609680  20.752865  0.146236
# 2   2019-01-12 14:56:00         2  91.0   52.399826  12.409351  0.146724
# 3   2019-01-12 14:57:00         3  92.0   41.708813  13.330035  0.143533
# 4   2019-01-12 14:58:00         4  90.0   52.926560  10.858296  0.142336
# ..                  ...       ...   ...         ...        ...       ...
# 65  2020-03-05 16:23:00       118  96.0  719.012700  12.886819  0.122251
# 66  2020-03-05 16:24:00       119  96.0  718.942600  12.846547  0.122363
# 67  2020-03-05 16:25:00       120  96.0  718.761960  11.103142  0.122447
# 68  2020-03-05 16:26:00       121  96.0  718.976200  13.124990  0.122398
# 69  2020-03-05 16:27:00       122  96.0  719.061460   7.817824  0.122540
#
#            PH         WT
# 0   12.359906  18.400787
# 1   12.825684  18.013641
# ...

# %%
g_data_4.to_csv('g_data_4.csv', index = False)
