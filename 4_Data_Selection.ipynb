# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivani-781/Ganga-Water-Quality-Assessment/blob/main/4_Data_Selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ganga Data Selection

# %% [markdown]
# Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %% [markdown]
# Reading dataset

# %%
df = pd.read_csv('Ganga_data.csv')

# %%
df
# Out:
#                    Date  Frame No   BAT        COND         DO       ORP  \
# 0      12-01-2019 12:57         0  91.0    0.044698  14.832754  0.084822
# 1      12-01-2019 12:58         1  92.0    0.044651  14.170345  0.086292
# 2      12-01-2019 14:54         0  90.0   46.195190  13.501176  0.142900
# 3      12-01-2019 14:55         1  91.0   52.609680  20.752865  0.146236
# 4      12-01-2019 14:56         2  91.0   52.399826  12.409351  0.146724
# ...                 ...       ...   ...         ...        ...       ...
# 46978  05-03-2020 17:40       193  87.0  721.867250  10.008608  0.116298
# 46979  05-03-2020 17:41       194  85.0  722.117000  10.008608  0.116288
# 46980  05-03-2020 17:42       195  80.0  722.028700  10.008608  0.116238
# 46981  05-03-2020 17:43       196  81.0  721.960700  10.008608  0.116218
# 46982  05-03-2020 17:44       197  83.0  722.114560  10.008608  0.116183
#
#               PH         WT
# 0       8.879727  22.650238
# 1       8.866815  22.567017
# ...

# %% [markdown]
# Applying Gaussian Distribution formula to check whether the data is in normal distribution or not.

# %%
#cond
cond = df['COND']
cond
# Out:
# 0          0.044698
# 1          0.044651
# 2         46.195190
# 3         52.609680
# 4         52.399826
#             ...
# 46978    721.867250
# 46979    722.117000
# 46980    722.028700
# 46981    721.960700
# 46982    722.114560
# Name: COND, Length: 46983, dtype: float64

# %%
cond.shape
# Out:
# (46983,)

# %%
cond_pdf = np.zeros([46983,1])

# %%
mu = np.mean(cond)
sigma = np.std(cond)

# %%
for i in range(0, 46983):
    x = 1/(np.sqrt(2*np.pi)*sigma)*np.exp(-np.power((cond[i] - mu)/sigma, 2)/2)
    cond_pdf[i] = x

# %%
cond_pdf
# Out:
# array([[0.00043646],
#        [0.00043646],
#        [0.00065844],
#        ...,
#        [0.00024008],
#        [0.00024026],
#        [0.00023985]])

# %%
plt.figure(figsize = (15,7))
plt.scatter(cond, cond_pdf, alpha = 0.5, marker = '.')
plt.xlabel('COND')
plt.ylabel('COND_PDF')
# Out:
# Text(0, 0.5, 'COND_PDF')

# %%
#do
do = df['DO']
do_pdf = np.zeros([46983,1])
mu = np.mean(do)
sigma = np.std(do)
for i in range(0, 46983):
    x = 1/(np.sqrt(2*np.pi)*sigma)*np.exp(-np.power((do[i] - mu)/sigma, 2)/2)
    do_pdf[i] = x
plt.figure(figsize = (15,7))
plt.scatter(do, do_pdf, alpha = 0.5, marker = '.')
plt.xlabel('DO')
plt.ylabel('DO_PDF')
# Out:
# Text(0, 0.5, 'DO_PDF')

# %%
#orp
orp = df['ORP']
orp_pdf = np.zeros([46983,1])
mu = np.mean(orp)
sigma = np.std(orp)
for i in range(0, 46983):
    x = 1/(np.sqrt(2*np.pi)*sigma)*np.exp(-np.power((orp[i] - mu)/sigma, 2)/2)
    orp_pdf[i] = x
plt.figure(figsize = (15,7))
plt.scatter(orp, orp_pdf, alpha = 0.5, marker = '.')
plt.xlabel('ORP')
plt.ylabel('ORP_PDF')
# Out:
# Text(0, 0.5, 'ORP_PDF')

# %% [markdown]
# Mean of ORP is above 10, so it is not normally distributed.

# %%
#ph
ph = df['PH']
ph_pdf = np.zeros([46983,1])
mu = np.mean(ph)
sigma = np.std(ph)
for i in range(0, 46983):
    x = 1/(np.sqrt(2*np.pi)*sigma)*np.exp(-np.power((ph[i] - mu)/sigma, 2)/2)
    ph_pdf[i] = x
plt.figure(figsize = (15,7))
plt.scatter(ph, ph_pdf, alpha = 0.5, marker = '.')
plt.xlabel('PH')
plt.ylabel('PH_PDF')
# Out:
# Text(0, 0.5, 'PH_PDF')

# %%
#WT
wt = df['WT']
wt_pdf = np.zeros([46983,1])
mu = np.mean(wt)
sigma = np.std(wt)
for i in range(0, 46983):
    x = 1/(np.sqrt(2*np.pi)*sigma)*np.exp(-np.power((wt[i] - mu)/sigma, 2)/2)
    wt_pdf[i] = x
plt.figure(figsize = (15,7))
plt.scatter(wt, wt_pdf, alpha = 0.5, marker = '.')
plt.xlabel('WT')
plt.ylabel('WT_PDF')
# Out:
# Text(0, 0.5, 'WT_PDF')

# %%
#bat
bat = df['BAT']
bat_pdf = np.zeros([46983,1])
mu = np.mean(bat)
sigma = np.std(bat)
for i in range(0, 46983):
    x = 1/(np.sqrt(2*np.pi)*sigma)*np.exp(-np.power((bat[i] - mu)/sigma, 2)/2)
    bat_pdf[i] = x
plt.figure(figsize = (15,7))
plt.scatter(do, do_pdf, alpha = 0.5, marker = '.')
plt.xlabel('BAT')
plt.ylabel('BAT_PDF')
# Out:
# Text(0, 0.5, 'BAT_PDF')

# %% [markdown]
# Plotting the relation between the attributes using Heatmap.

# %%
dfc = df[['COND', 'DO', 'ORP', 'PH', 'WT']]
dfc.corr()
# Out:
#           COND        DO       ORP        PH        WT
# COND  1.000000 -0.721896 -0.086301 -0.198614 -0.315520
# DO   -0.721896  1.000000  0.143362  0.260881  0.288068
# ORP  -0.086301  0.143362  1.000000  0.104437  0.113377
# PH   -0.198614  0.260881  0.104437  1.000000  0.152032
# WT   -0.315520  0.288068  0.113377  0.152032  1.000000

# %%
plt.figure(figsize = (10, 8))
sns.heatmap(dfc.corr(), annot = True)
plt.show()
